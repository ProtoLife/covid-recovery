# %% [markdown]
# # Map of Covid-19 Deaths/Cases Clustering

# %%
import folium
import pandas as pd

# %%
import pickle as pk

# %%
#Setting up the world countries data URL
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %% [markdown]
# Read data from Cluster notebook

# %%
with open('clusalign.pk','rb') as fp:
    clusalign = pk.load(fp)
    
clusalign;

# %%
df = []
for cc in clusalign:
    for country in clusalign[cc]:
        if cc == -1:
            df.append([country,1])
        if cc == 0:
            df.append([country,2])
        if cc == 1:
            df.append([country,3])
        if cc == 2:
            df.append([country,4])
        if cc == 3:
            df.append([country,5])
        if cc == 4:
            df.append([country,6])
df_clusalign = pd.DataFrame(df, columns = ['Country', 'Total Case'])

# %%
df_clusalign.replace('United States', 'United States of America', inplace=True)
#Replacing the country name
df_clusalign.replace('USA', "United States of America", inplace = True)
df_clusalign.replace('Tanzania', "United Republic of Tanzania", inplace = True)
df_clusalign.replace('Democratic Republic of Congo', "Democratic Republic of the Congo", inplace = True)
df_clusalign.replace('Congo', "Republic of the Congo", inplace = True)
df_clusalign.replace('Lao', "Laos", inplace = True)
df_clusalign.replace('Syrian Arab Republic', "Syria", inplace = True)
df_clusalign.replace('Serbia', "Republic of Serbia", inplace = True)
df_clusalign.replace('Czechia', "Czech Republic", inplace = True)
df_clusalign.replace('UAE', "United Arab Emirates", inplace = True)

# %%
m = folium.Map(location=[5., 12.],zoom_start=2)
#Adding the Choropleth layer onto our base map
chorop = folium.Choropleth(
    #The GeoJSON data to represent the world country
    geo_data=country_shapes,
    name='choropleth COVID-19',
    data=df_clusalign,
    #The column aceppting list with 2 value; The country name and  the numerical value
    columns=['Country', 'Total Case'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    fill_color='Spectral',
    nan_fill_color='white'
).add_to(m)
m;

# %% [markdown]
# **Remove legend**

# %%
m = folium.Map(location=[5., 12.],zoom_start=2)
#Adding the Choropleth layer onto our base map
chorop = folium.Choropleth(
    #The GeoJSON data to represent the world country
    geo_data=country_shapes,
    name='choropleth COVID-19',
    data=df_clusalign,
    #The column aceppting list with 2 value; The country name and  the numerical value
    columns=['Country', 'Total Case'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    fill_color='Spectral',
    nan_fill_color='white'
)
# following loop removes legend.
for kk in chorop._children:
    if kk.startswith('color_map'):
        del chorop._children[kk]
chorop.add_to(m)
m

# %%
m.save('consensus.html')
#then use screengrab + Preview to convert to png

# %% [markdown]
# ## Ref col 22

# %%
with open('clusalign22.pk','rb') as fp:
    clusalign = pk.load(fp)
    
clusalign;

# %%
df = []
for cc in clusalign:
    for country in clusalign[cc]:
        if cc == -1:
            df.append([country,1])
        if cc == 0:
            df.append([country,2])
        if cc == 1:
            df.append([country,3])
        if cc == 2:
            df.append([country,4])
        if cc == 3:
            df.append([country,5])
        if cc == 4:
            df.append([country,6])
df_clusalign = pd.DataFrame(df, columns = ['Country', 'Total Case'])

# %%
df_clusalign.replace('United States', 'United States of America', inplace=True)
#Replacing the country name
df_clusalign.replace('USA', "United States of America", inplace = True)
df_clusalign.replace('Tanzania', "United Republic of Tanzania", inplace = True)
df_clusalign.replace('Democratic Republic of Congo', "Democratic Republic of the Congo", inplace = True)
df_clusalign.replace('Congo', "Republic of the Congo", inplace = True)
df_clusalign.replace('Lao', "Laos", inplace = True)
df_clusalign.replace('Syrian Arab Republic', "Syria", inplace = True)
df_clusalign.replace('Serbia', "Republic of Serbia", inplace = True)
df_clusalign.replace('Czechia', "Czech Republic", inplace = True)
df_clusalign.replace('UAE', "United Arab Emirates", inplace = True)

# %%
m = folium.Map(location=[5., 12.],zoom_start=2)
#Adding the Choropleth layer onto our base map
chorop = folium.Choropleth(
    #The GeoJSON data to represent the world country
    geo_data=country_shapes,
    name='choropleth COVID-19',
    data=df_clusalign,
    #The column aceppting list with 2 value; The country name and  the numerical value
    columns=['Country', 'Total Case'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    fill_color='Spectral',
    nan_fill_color='white'
).add_to(m)
m

# %% [markdown]
# **Remove legend**

# %%
m = folium.Map(location=[5., 12.],zoom_start=2)
#Adding the Choropleth layer onto our base map
chorop = folium.Choropleth(
    #The GeoJSON data to represent the world country
    geo_data=country_shapes,
    name='choropleth COVID-19',
    data=df_clusalign,
    #The column aceppting list with 2 value; The country name and  the numerical value
    columns=['Country', 'Total Case'],
    key_on='feature.properties.name',
    # fill_color='YlGn',
    fill_color='Spectral',
    nan_fill_color='white'
)
# following loop removes legend.
for kk in chorop._children:
    if kk.startswith('color_map'):
        del chorop._children[kk]
chorop.add_to(m)
m

# %%
m.save('consensus.html')
#then use screengrab + Preview to convert to png

# %% [markdown]
# # Other

# %%
import pandas as pd
import geopandas as gpd
import folium
import branca.colormap as cm
import pickle as pk

# %%
#Setting up the world countries data URL
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes = f'{url}/world-countries.json'

# %%
country_shapes;

# %%
fname = country_shapes
geog = gpd.read_file(fname)
geog.head();

# %%
with open('clusalign_hsv.pk','rb') as fp:
    clusalign_hsv = pk.load(fp)
    
clusalign_hsv;

# %%
dflist = [[term]+list(clusalign_hsv[term]) for term in clusalign_hsv]
df = pd.DataFrame(dflist, columns = ['name', 'cluster','hue','sat','val'])

# %%
df.replace('United States', 'United States of America', inplace=True)
df.replace('USA', "United States of America", inplace = True)
df.replace('Tanzania', "United Republic of Tanzania", inplace = True)
df.replace('Democratic Republic of Congo', "Democratic Republic of the Congo", inplace = True)
df.replace('Congo', "Republic of the Congo", inplace = True)
df.replace('Lao', "Laos", inplace = True)
df.replace('Syrian Arab Republic', "Syria", inplace = True)
df.replace('Serbia', "Republic of Serbia", inplace = True)
df.replace('Czechia', "Czech Republic", inplace = True)
df.replace('UAE', "United Arab Emirates", inplace = True)

# %%
geogclus=geog.merge(df,on='name')
geogclus;

# %%
def rgb_to_str(rgb):
    return '#%02x%02x%02x' % (int(rgb[0]*255),int(rgb[1]*255),int(rgb[2]*255))

def colorit(x):
    h = x['properties']['hue']
    s = x['properties']['sat']
    v = x['properties']['val']
    rgb = list(mpcolors.hsv_to_rgb([h,s,v]))
    return rgb_to_str(rgb)

# %%
from matplotlib import colors as mpcolors
mymap = folium.Map(location=[5., 12.],zoom_start=2,tiles=None)
folium.TileLayer('CartoDB positron',name="Light Map",control=False).add_to(mymap)

style_function = lambda x: {"weight":0.5, 
                            'color':'black',
                            #'fillColor':colormap(x['properties']['hue']), 
                            'fillColor':colorit(x), 
                            'fillOpacity':1.0}
highlight_function = lambda x: {'fillColor': colorit(x), 
                                'color':'#000000', 
                                'fillOpacity': 0.5, 
                                'weight': 0.1}
CLUS=folium.features.GeoJson(
        geogclus,
        style_function=style_function,
        control=False,
        highlight_function=highlight_function,
        tooltip=folium.features.GeoJsonTooltip(fields=['name','cluster'],
            aliases=['Country','hue of cluster'],
            style=("background-color: white; color: #333333; font-family: arial; font-size: 12px; padding: 10px;"),
            sticky=True
        )
    )

mymap.add_child(CLUS)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mymap.save('index.html')
